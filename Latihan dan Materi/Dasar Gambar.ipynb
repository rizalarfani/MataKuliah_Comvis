# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %% [markdown]
# # Apa yang di lihat Mesin

# %%
img = cv2.imread('Bahan/1.png')
print(img)
# Out:
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [213 159  46]
#   [213 160  44]
#   [213 160  44]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [213 159  46]
#   [213 160  44]
#   [213 160  44]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [213 160  44]
#   [213 159  45]
#   [213 159  45]]]

# %%
img = cv2.imread('Bahan/1.png')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.title('Gambar Pertama')
plt.show()
cv2.imshow('gambar',img)
cv2.waitKey()
cv2.destroyAllWindows()
